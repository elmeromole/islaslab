# %%
from pylab import *
# %matplotlib inline

# %%
def func(x):
    y= x**2
    return y

# %%
x = linspace (0,2)
plot (x,func(x))

# %% [markdown]
# $$
# f'(x) = \frac{f(x+h)-f(x)}{h}
# $$

# %%
def derivador(func,x,h):
    y = (func(x+h) - func(x))/h
    return y

# %%
plot (x,func(x))
plot (x,derivador(func,x,0.001))
plot (x,2*x)

# %%
plot (x,func(x))
plot (x,derivador(func,x,0.5))
plot (x,2*x)

# %% [markdown]
# Función que queremos integrar es
#
# $$
# y'(x) = func (x)
# $$
#
# $$
# y'(x) = y(x)
# $$
#
# $$
# y(x) = Ae^x
# $$

# %%
def mi_ec_dif(y,x):
    return y

# %% [markdown]
# $$
# \int_{x_i}^{x_i + h} y'(x) \simeq y_{i} + h y(x_i)
# $$

# %%
def euler (func,p_ini,h,x_f):
    pasos = arange(p_ini[0],x_f+h, h)
    y = zeros (len(pasos))
    y[0] = p_ini[1]
    for i in range(len(pasos)-1):
        y[i+1] = y[i] + h*func(y[i],pasos[i])
    solucion = [pasos, y]
    return solucion

# %%
arange(1,4,0.2)
# Out:
# array([ 1. ,  1.2,  1.4,  1.6,  1.8,  2. ,  2.2,  2.4,  2.6,  2.8,  3. ,
#         3.2,  3.4,  3.6,  3.8])

# %%
sol = euler(mi_ec_dif,[0,1],0.001,10)
plot (sol[0],sol[1],sol[0],exp(sol[0]))

# %%
sol = euler(mi_ec_dif,[0,1],0.01,200)
plot (sol[0],sol[1],sol[0],exp(sol[0]))
xlim(170,200)
# Out:
# (170, 200)

# %%
sol = euler(mi_ec_dif,[0,1],0.01,200)
plot (sol[0],sol[1],sol[0],exp(sol[0]))
xlim(170,200)
# Out:
# (170, 200)

# %%
sol = euler(mi_ec_dif,[0,1],0.1,10)
plot (sol[0],sol[1],sol[0],exp(sol[0]))

# %% [markdown]
# $$
# y'x= -xy(x)
# $$
#
# $$
# y(x) = Ae^{\frac{-x^2}{2}}
# $$

# %%
def ec_2(y,x):
    return -x*y

# %%
sol = euler(ec_2,[0,1],0.01,10)
plot (sol[0],sol[1],sol[0],exp((-sol[0]**2)/2))

# %%
sol = euler(ec_2,[0,1],0.5,10)
plot (sol[0],sol[1],sol[0],exp((-sol[0]**2)/2))
