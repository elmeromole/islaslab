# %% [markdown]
# Clase 2

# %%
from pylab import *
# %matplotlib inline

# %%
def func (x):
    #tabulador es importante para jerarquizar los comandos
    y= x**2
    return y

# %%
linspace (0,2)
# para definir un numero de valores en respuesta se pone una coma -,- despues del dos y defines cuantas respuestas quieres
# Out:
# array([ 0.        ,  0.04081633,  0.08163265,  0.12244898,  0.16326531,
#         0.20408163,  0.24489796,  0.28571429,  0.32653061,  0.36734694,
#         0.40816327,  0.44897959,  0.48979592,  0.53061224,  0.57142857,
#         0.6122449 ,  0.65306122,  0.69387755,  0.73469388,  0.7755102 ,
#         0.81632653,  0.85714286,  0.89795918,  0.93877551,  0.97959184,
#         1.02040816,  1.06122449,  1.10204082,  1.14285714,  1.18367347,
#         1.2244898 ,  1.26530612,  1.30612245,  1.34693878,  1.3877551 ,
#         1.42857143,  1.46938776,  1.51020408,  1.55102041,  1.59183673,
#         1.63265306,  1.67346939,  1.71428571,  1.75510204,  1.79591837,
#         1.83673469,  1.87755102,  1.91836735,  1.95918367,  2.        ])

# %%
x = linspace(0,2)
plot(x,func(x))

# %%
def func2(x):
    y = x**3
    return y

# %%
a = "hola mundo"
def hola():
    a = "hola de nuevo"
    print a
print a
hola ()
# Out:
# hola mundo
# hola de nuevo

# %%
y = func(x)
z = func2(x)
plot(x,y)
plot(x,z)
xlim(0,1)
ylim(0,1)
# Out:
# (0, 1)

# %%
puntosy =[1,3,2,5,0.2]
puntosx =[0,1,2,3,4]
plot (puntosx, puntosy, 'o')
plot (x,func (x))
# comando show antes de plot muestra gráficas en separado

# %%
def func3(x,exponente) :
    return x**exponente

# %%
for i in range(3):
    y=func3(x,i)
    plot(x,y)

# %%
range (3)
# no usa fracciones
# Out:
# [0, 1, 2]

# %%
arange (0, 2, 0.5)
# usa fracciones
# Out:
# array([ 0. ,  0.5,  1. ,  1.5])

# %%
platillos = [100,130,30]
len(platillos)
# Out:
# 3

# %%
def cuenta (platillos,propina):
    total = 0
    for i in range (len(platillos)):
        total += platillos[i]
    
    total= total + total*propina
    print total

# %%
platillos = [50,23,40,121,154]
propina = 0.1
cuenta(platillos,propina)
# Out:
# 426.8
